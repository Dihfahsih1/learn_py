# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns
import plotly.express as px
sns.set_style('white', { 'axes.spines.right': False, 'axes.spines.top': False})
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support as score, roc_curve
from sklearn.model_selection import cross_val_score, train_test_split, cross_validate
from sklearn.utils import compute_sample_weight
from xgboost import XGBClassifier

df = pd.read_csv('predictive_maintenance.csv')
target_name = 'Failure Type'

# drop a redundant columns
df.drop(columns=['Target'], inplace=True)

# print a summary of the train data
print(df.shape[0])
df.head(101)
# Out:
# 10000
#     Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0       M14860    M                298.1                    308.6
# 1       L47181    L                298.2                    308.7
# 2       L47182    L                298.1                    308.5
# 3       L47183    L                298.2                    308.6
# 4       L47184    L                298.2                    308.7
# ..         ...  ...                  ...                      ...
# 96      M14956    M                299.0                    309.0
# 97      M14957    M                298.9                    308.9
# 98      L47278    L                298.9                    308.8
# 99      L47279    L                298.8                    308.8
# 100     L47280    L                298.8                    308.9
#
#      Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                      1551         42.8                0       0   No Failure
# 1                      1408         46.3                3       0   No Failure
# 2                      1498         49.4                5       0   No Failure
# 3                      1433         39.5                7       0   No Failure
# 4                      1408         40.0                9       0   No Failure
# ..                      ...          ...              ...     ...          ...
# 96                     1575         35.3               47       0   No Failure
# 97                     1750         29.9               50       0   No Failure
# 98                     1529         32.7               53       0   No Failure
# 99                     1523         44.4               55       0   No Failure
# 100                    1852         25.0               57       0   No Failure
#
# [101 rows x 9 columns]
